# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from itertools import permutations

# %%
df=pd.read_csv("Clustering_Data.csv")
sol=pd.read_csv("Clustering_Data.csv", usecols=["Customer_Segment"])
df=df.drop("Customer_Segment", axis=1)

# %%
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
sol
# Out:
#      Customer_Segment
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ..                ...
# 173                 3
# 174                 3
# 175                 3
# 176                 3
# 177                 3
#
# [178 rows x 1 columns]

# %%
df.shape
# Out:
# (178, 13)

# %%
df.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
dfmean=df.mean()
dfstd=df.std()
df=(df-dfmean)/dfstd

# %%
df=df.to_numpy()

# %%
def kmeans(df,k,iterations=300):
    clusters=df[np.random.choice(len(df),size=(k))]
    j=0
    while (j<=iterations):
        old_clusters=clusters.copy()
        assignments=[]
        for i in df:
            distances = np.linalg.norm(clusters - i, axis=1)
            cluster_index = np.argmin(distances)
            assignments.append(cluster_index)
            
        assignments=np.array(assignments)
        for i in range(k):
            cluster_points = df[assignments == i]
            if len(cluster_points) > 0:
                clusters[i] = cluster_points.mean(axis=0)
            else:
                clusters[i] = df[np.random.choice(len(df))]

            clusters[i]=np.mean(df[assignments==i])
            
        shift = np.linalg.norm(clusters - old_clusters)
        if shift < 1e-40:
            print("Converged after",j,"iterations")
            return clusters, assignments   
        j+=1

# %%
clusters, assignments = kmeans(df,3)
# Out:
# Converged after 15 iterations

# %%
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(df)
reduced_clusters = pca.transform(clusters)

plt.figure(figsize=(8, 6))
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=assignments, cmap='viridis')
plt.scatter(reduced_clusters[:, 0], reduced_clusters[:, 1], c='red', s=200, marker='X')
plt.title('K-Means Clustering (PCA-Reduced)')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

# Plot predicted clusters
plt.subplot(1, 2, 1)
plt.scatter(df_pca[:, 0], df_pca[:, 1], c=assignments, cmap='viridis')
plt.title('Predicted Clusters')

# Plot true labels
plt.subplot(1, 2, 2)
plt.scatter(df_pca[:, 0], df_pca[:, 1], c=sol, cmap='viridis')
plt.title('True Labels')

plt.show()

# %%
sol.to_numpy()
print(sol.shape)
print(assignments.shape)
# Out:
# (178, 1)
# (178,)

# %%
def clustering_accuracy(assignments, sol, k):
    best_accuracy = 0
    best_mapping = None

    for perm in permutations(range(k)):
        mapped = np.array([perm[label] for label in assignments])
        acc = np.mean(mapped == sol)
        if acc > best_accuracy:
            best_accuracy = acc
            best_mapping = perm

    return best_accuracy, best_mapping

# %%
assignments = np.array(assignments)
sol = np.array(sol).ravel()
k = len(set(sol))  # or len(np.unique(assignments))

# Compute accuracy
accuracy, mapping = clustering_accuracy(assignments, sol, k)

# Output
print(f"Accuracy: {accuracy}")
print(f"Best cluster-to-label mapping: {mapping}")
# Out:
# Accuracy: 0.449438202247191
# Best cluster-to-label mapping: (0, 2, 1)
