# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train=pd.read_csv('Seniors.csv', usecols=['Temperature (°C)','Pressure (kPa)','Temperature x Pressure','Material Fusion Metric','Material Transformation Metric'])
Y_train=pd.read_csv('Seniors.csv', usecols=['Quality Rating'])

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (2500, 5)
# (2500, 1)

# %%
X_train.head
# Out:
# <bound method NDFrame.head of       Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 0           209.762701        8.050855             1688.769167
# 1           243.037873       15.812068             3842.931469
# 2           220.552675        7.843130             1729.823314
# 3           208.976637       23.786089             4970.736918
# 4           184.730960       15.797812             2918.345014
# ...                ...             ...                     ...
# 2495        194.332813       22.269402             4327.675524
# 2496        240.467829       15.981486             3843.033197
# 2497        244.866196       24.901641             6097.570183
# 2498        138.314203       10.700640             1480.050534
# 2499        232.434847        6.374536             1481.664374
#
#       Material Fusion Metric  Material Transformation Metric
# 0               44522.217074                    9.229576e+06
# ...

# %%
Y_train.head
# Out:
# <bound method NDFrame.head of       Quality Rating
# 0          99.999971
# 1          99.985703
# 2          99.999758
# 3          99.999975
# 4         100.000000
# ...              ...
# 2495       99.999999
# 2496       99.990852
# 2497       99.980421
# 2498      100.000000
# 2499       99.997804
#
# [2500 rows x 1 columns]>

# %%
X_train.describe()
# Out:
#        Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# count       2500.000000     2500.000000             2500.000000
# mean         200.653802       14.800937             2966.560892
# std           58.615971        5.704845             1461.402337
# min          100.014740        5.009819              513.706875
# 25%          150.875184        9.821192             1800.528733
# 50%          200.291585       14.864597             2708.227080
# 75%          251.811806       19.722411             3929.471504
# max          299.961716       24.999132             7365.018714
#
#        Material Fusion Metric  Material Transformation Metric
# count             2500.000000                    2.500000e+03
# mean             48385.166770                    1.014740e+07
# std              24053.925674                    7.678297e+06
# min              10156.971955                    9.999462e+05
# 25%              27504.622582                    3.434285e+06
# ...

# %%
X_train['Material Transformation Metric']=np.log(X_train['Material Transformation Metric'])
X_train['Material Fusion Metric']=np.log(X_train['Material Fusion Metric'])
X_train['Temperature x Pressure']=np.log(X_train['Temperature x Pressure'])

# %%
X_train.describe()
# Out:
#        Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# count       2500.000000     2500.000000             2500.000000
# mean         200.653802       14.800937                7.863160
# std           58.615971        5.704845                0.534852
# min          100.014740        5.009819                6.241653
# 25%          150.875184        9.821192                7.495835
# 50%          200.291585       14.864597                7.904049
# 75%          251.811806       19.722411                8.276260
# max          299.961716       24.999132                8.904497
#
#        Material Fusion Metric  Material Transformation Metric
# count             2500.000000                     2500.000000
# mean                10.644128                       15.765796
# std                  0.561123                        0.934738
# min                  9.225916                       13.815457
# 25%                 10.222109                       15.049319
# ...

# %%
Y_train.describe()
# Out:
#        Quality Rating
# count     2500.000000
# mean        96.039307
# std         13.306205
# min          1.421653
# 25%         99.936589
# 50%         99.999996
# 75%        100.000000
# max        100.000000

# %%
Y_train.corrwith(X_train)
# Out:
# Material Fusion Metric           NaN
# Material Transformation Metric   NaN
# Pressure (kPa)                   NaN
# Quality Rating                   NaN
# Temperature (°C)                 NaN
# Temperature x Pressure           NaN
# dtype: float64

# %%
X_train.isna().sum()
# Out:
# Temperature (°C)                  0
# Pressure (kPa)                    0
# Temperature x Pressure            0
# Material Fusion Metric            0
# Material Transformation Metric    0
# dtype: int64

# %%
Y_train.isna().sum()
# Out:
# Quality Rating    0
# dtype: int64
