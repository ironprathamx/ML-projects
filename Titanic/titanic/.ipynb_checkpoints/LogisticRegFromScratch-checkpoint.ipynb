# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h1>Exploratory Data Analysis / Preprocessing</h1>

# %%
X_train=pd.read_csv('train.csv')
Y_train=pd.read_csv('train.csv', usecols=['Survived'])
X_test=pd.read_csv('test.csv')
Y_test=pd.read_csv('gender_submission.csv')
X=pd.read_csv('train.csv')

# %%
X_train=X_train.drop(columns=['PassengerId','Survived','Name','Ticket'])
X_test=X_test.drop(columns=['PassengerId'])

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (891, 8)
# (891, 1)

# %%
X_train.isna().sum()
# Out:
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
X_train['Cabin'].str[0].unique()
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
X_train
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         3    male  22.0      1      0   7.2500   NaN        S
# 1         1  female  38.0      1      0  71.2833   C85        C
# 2         3  female  26.0      0      0   7.9250   NaN        S
# 3         1  female  35.0      1      0  53.1000  C123        S
# 4         3    male  35.0      0      0   8.0500   NaN        S
# ..      ...     ...   ...    ...    ...      ...   ...      ...
# 886       2    male  27.0      0      0  13.0000   NaN        S
# 887       1  female  19.0      0      0  30.0000   B42        S
# 888       3  female   NaN      1      2  23.4500   NaN        S
# 889       1    male  26.0      0      0  30.0000  C148        C
# 890       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 8 columns]

# %%
def preprocessing(X_train):
    X_train['Has_Cabin']=~X_train['Cabin'].isna()
    X_train['Cabin_Class'] = X_train['Cabin'].str[0]
    X_train['Cabin_Class'] = X_train['Cabin_Class'].fillna('Unknown')
    X_train.drop('Cabin', axis=1, inplace=True)
    X_train['Age'] = X_train['Age'].fillna(X_train['Age'].median())
    X_train=pd.get_dummies(X_train,columns=['Embarked','Sex','Cabin_Class'])
    return X_train

# %%
X_train=preprocessing(X_train)

# %%
X_train
# Out:
#      Pclass   Age  SibSp  Parch     Fare  Has_Cabin  Embarked_C  Embarked_Q  \
# 0         3  22.0      1      0   7.2500      False       False       False
# 1         1  38.0      1      0  71.2833       True        True       False
# 2         3  26.0      0      0   7.9250      False       False       False
# 3         1  35.0      1      0  53.1000       True       False       False
# 4         3  35.0      0      0   8.0500      False       False       False
# ..      ...   ...    ...    ...      ...        ...         ...         ...
# 886       2  27.0      0      0  13.0000      False       False       False
# 887       1  19.0      0      0  30.0000       True       False       False
# 888       3  28.0      1      2  23.4500      False       False       False
# 889       1  26.0      0      0  30.0000       True        True       False
# 890       3  32.0      0      0   7.7500      False       False        True
#
#      Embarked_S  Sex_female  Sex_male  Cabin_Class_A  Cabin_Class_B  \
# 0          True       False      True          False          False
# 1         False        True     False          False          False
# 2          True        True     False          False          False
# 3          True        True     False          False          False
# 4          True       False      True          False          False
# ..          ...         ...       ...            ...            ...
# 886        True       False      True          False          False
# 887        True        True     False          False           True
# 888        True        True     False          False          False
# 889       False       False      True          False          False
# 890       False       False      True          False          False
#
#      Cabin_Class_C  Cabin_Class_D  Cabin_Class_E  Cabin_Class_F  \
# 0            False          False          False          False
# 1             True          False          False          False
# 2            False          False          False          False
# 3             True          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 886          False          False          False          False
# 887          False          False          False          False
# 888          False          False          False          False
# 889           True          False          False          False
# 890          False          False          False          False
#
#      Cabin_Class_G  Cabin_Class_T  Cabin_Class_Unknown
# 0            False          False                 True
# 1            False          False                False
# 2            False          False                 True
# 3            False          False                False
# 4            False          False                 True
# ..             ...            ...                  ...
# 886          False          False                 True
# 887          False          False                False
# 888          False          False                 True
# 889          False          False                False
# 890          False          False                 True
#
# [891 rows x 20 columns]

# %%
Y_train
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
Y_train.nunique()
# Out:
# Survived    2
# dtype: int64

# %% [markdown]
# <h2>Outlier Detection</h2>

# %%
X_train.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.836071   13.019697    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   35.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data=pd.concat([X_train,Y_train],axis=1)
corr=data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
Xmean=X_train.mean()
Xstd=X_train.std()
def norm(X):
    return ((X-Xmean)/Xstd)

# %%
X_train=norm(X_train)
X_test=norm(X_test)

# %%
X_train.isna().sum()
# Out:
# Pclass                 0
# Age                    0
# SibSp                  0
# Parch                  0
# Fare                   0
# Has_Cabin              0
# Embarked_C             0
# Embarked_Q             0
# Embarked_S             0
# Sex_female             0
# Sex_male               0
# Cabin_Class_A          0
# Cabin_Class_B          0
# Cabin_Class_C          0
# Cabin_Class_D          0
# Cabin_Class_E          0
# Cabin_Class_F          0
# Cabin_Class_G          0
# Cabin_Class_T          0
# Cabin_Class_Unknown    0
# dtype: int64

# %%
X_train = X_train.to_numpy()
X_test=X_test.to_numpy()
Y_train = Y_train.to_numpy()
Y_test=Y_test.to_numpy()

# %% [markdown]
# <h1>Training</h1>

# %%
def z_calc(X,W,B):
    Z=np.matmul(X,W)+B
    Z = np.clip(Z, -500, 500)
    return Z

def g_calc(Z):
    return 1/(1+np.exp(-Z))

def compute_cost(Y_train,G_train,W_train,lambd=0):
    epsilon=1e-15
    G_train=np.clip(G_train, epsilon, 1 - epsilon)
    cost=-(Y_train*np.log(G_train)+(1-Y_train)*np.log(1-G_train))/G_train.shape[0]
    reg = (lambd / (2 * Y_train.size)) * np.sum(W_train**2)
    return cost.sum()+reg

# %%
W_train = np.ones((X_train.shape[1], 1))
B_train= 0.0

# %%
Z_train=z_calc(X_train,W_train,B_train)
G_train=g_calc(Z_train)
P_train=np.round(G_train)

# %%
print(X_train.shape)
print(Y_train.shape)
print(Z_train.shape)
# Out:
# (891, 20)
# (891, 1)
# (891, 1)

# %%
W_history=[]
B_history=[]
P_history=[]
J_history=[]
W_history.append(W_train)
B_history.append(B_train)
P_history.append(P_train)
J_history.append(compute_cost(Y_train,G_train,W_train))

# %%
def gradescent(epoch, alpha, W_history, J_history, B_history, P_history, X_train, Y_train, lambd=0):
    for i in range(epoch):
        W_current = W_history[-1]
        B_current = B_history[-1]

        Z_train = z_calc(X_train, W_current, B_current)
        G_train = g_calc(Z_train)

        # Gradient updates
        W_new = W_current - alpha* (X_train.T @ (G_train - Y_train) + lambd * W_current) / X_train.shape[0] 
        B_new = B_current - alpha / X_train.shape[0] * np.sum(G_train - Y_train)

        # Append new weights and biases
        W_history.append(W_new.copy())
        B_history.append(B_new)

        # Prediction and cost
        Z_train = z_calc(X_train, W_new, B_new)
        G_train = g_calc(Z_train)
        P_history.append(np.round(G_train))
        J_history.append(compute_cost(Y_train, G_train,W_history[-1]))

        if i % 10 == 0:
            print("Iteration:", i, "Cost:", J_history[-1])

# %%
epoch=3000
alpha=4.5
gradescent(epoch, alpha, W_history, J_history, B_history, P_history, X_train, Y_train)
# Out:
# Iteration: 0 Cost: 0.7045349893727528
# Iteration: 2730 Cost: 0.5385104028823878
# Iteration: 2740 Cost: 0.5385099949660015
# Iteration: 2750 Cost: 0.5385095903288872
# Iteration: 2760 Cost: 0.538509188932479
# Iteration: 2770 Cost: 0.5385087907388048
# Iteration: 2780 Cost: 0.5385083957104729
# Iteration: 2790 Cost: 0.5385080038106627
# Iteration: 2800 Cost: 0.5385076150031127
# Iteration: 2810 Cost: 0.5385072292521114
# Iteration: 2820 Cost: 0.5385068465224856
# Iteration: 2830 Cost: 0.538506466779592
# Iteration: 2840 Cost: 0.5385060899893059
# Iteration: 2850 Cost: 0.5385057161180129
# Iteration: 2860 Cost: 0.5385053451325983
# Iteration: 2870 Cost: 0.5385049770004391
# Iteration: 2880 Cost: 0.5385046116893948
# Iteration: 2890 Cost: 0.5385042491677978
# Iteration: 2900 Cost: 0.5385038894044454
# Iteration: 2910 Cost: 0.5385035323685922
# Iteration: 2920 Cost: 0.5385031780299404
# Iteration: 2930 Cost: 0.5385028263586329
# Iteration: 2940 Cost: 0.5385024773252444
# Iteration: 2950 Cost: 0.5385021309007751
# Iteration: 2960 Cost: 0.5385017870566419
# Iteration: 2970 Cost: 0.5385014457646717
# Iteration: 2980 Cost: 0.5385011069970935
# Iteration: 2990 Cost: 0.5385007707265328

# %%
#best cost: Iteration: 990 Cost: 0.30232651808472094
#Iteration: 2990 Cost: 0.2964052591711286

# %%
plt.plot(J_history)

# %%
W_train=W_history[-1]
B_train=B_history[-1]
Z_train=z_calc(X_train,W_train,B_train)
G_train=g_calc(Z_train)
P_train=np.round(G_train)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_train, P_train)  
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_train, P_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.82       549
#            1       0.72      0.65      0.68       342
#
#     accuracy                           0.77       891
#    macro avg       0.76      0.75      0.75       891
# weighted avg       0.76      0.77      0.77       891

# %%
count=0
for i in range(len(P_train)):
    if (P_train[i]==Y_train[i]):
        count+=1
print("Accuracy: ",count*100/len(P_train))
# Out:
# Accuracy:  76.76767676767676

# %%
# Accuracy 1 (Initial): 76.767676

# %% [markdown]
# <h1>Testing</h1>

# %%
X_test=preprocessing(X_test)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 X_test=preprocessing(X_test)
#
# Cell In[23], line 2, in preprocessing(X_train)
#       1 def preprocessing(X_train):
# ----> 2     X_train['Has_Cabin']=~X_train['Cabin'].isna()
#       3     X_train['Cabin_Class'] = X_train['Cabin'].str[0]
#       4     X_train['Cabin_Class'] = X_train['Cabin_Class'].fillna('Unknown')
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
y_pred=z_calc(X_test,W_train,B_train)
g_pred=g_calc(y_pred)
p_pred=np.round(g_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 y_pred=z_calc(X_test,W_train,B_train)
#       2 g_pred=g_calc(y_pred)
#       3 p_pred=np.round(g_pred)
#
# Cell In[34], line 2, in z_calc(X, W, B)
#       1 def z_calc(X,W,B):
# ----> 2     Z=np.matmul(X,W)+B
#       3     Z = np.clip(Z, -500, 500)
#       4     return Z
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 20 is different from 25)

# %%
cm = confusion_matrix(Y_test, p_pred)  
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(Y_test, p_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      0.88      0.89       268
#         True       0.87      0.89      0.88       232
#
#     accuracy                           0.89       500
#    macro avg       0.89      0.89      0.89       500
# weighted avg       0.89      0.89      0.89       500

# %%
count=0
for i in range(len(p_pred)):
    if (p_pred[i]==Y_test[i]):
        count+=1
print("Accuracy: ",count*100/len(p_pred))
# Out:
# Accuracy:  88.6
