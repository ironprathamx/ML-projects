# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h1>Exploratory Data Analysis / Preprocessing</h1>

# %%
X_train=pd.read_csv('train.csv')
Y_train=pd.read_csv('train.csv', usecols=['Survived'])
X_test=pd.read_csv('test.csv')
Y_test=pd.read_csv('gender_submission.csv')
X=pd.read_csv('train.csv')

# %%
X_train=X_train.drop(columns=['PassengerId','Survived'])
X_test=X_test.drop(columns=['PassengerId'])

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (891, 10)
# (891, 1)

# %%
X_train.isna().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
X_train['Cabin'].str[0].unique()
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
X_train
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 886       2                              Montvila, Rev. Juozas    male  27.0
# 887       1                       Graham, Miss. Margaret Edith  female  19.0
# 888       3           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889       1                              Behr, Mr. Karl Howell    male  26.0
# 890       3                                Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 10 columns]

# %%
def preprocessing(X_train):
    X_train['Has_Cabin']=~X_train['Cabin'].isna()
  # 1 X_train['Ticket_Prefix'] = X_train['Ticket'].str.replace('[^A-Za-z]', '', regex=True)   #
  #  1X_train['Ticket_Prefix'].replace('', 'NONE', inplace=True)  # no prefix case
   # 2ticket_counts = X_train['Ticket'].value_counts()
   # 2X_train['Ticket_GroupSize'] = X_train['Ticket'].map(ticket_counts)
   # 2X_train['Is_Shared_Ticket'] = (X_train['Ticket_GroupSize'] > 1).astype(int)
    X_train['Title'] = X_train['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
    title_mapping = {
        "Mlle": "Miss",
        "Ms": "Miss",
        "Mme": "Mrs",
        "Lady": "Royalty",
        "Countess": "Royalty",
        "Dona": "Royalty",
        "Dr": "Officer",
        "Rev": "Officer",
        "Col": "Officer",
        "Major": "Officer",
        "Capt": "Officer",
        "Sir": "Royalty",
        "Don": "Royalty",
        "Jonkheer": "Royalty"
    }

    X_train['Title'] = X_train['Title'].replace(title_mapping)

    X_train['Cabin_Class'] = X_train['Cabin'].str[0]
    X_train['Cabin_Class'] = X_train['Cabin_Class'].fillna('Unknown')
    X_train['Age'] = X_train['Age'].fillna(X_train['Age'].median())
    X_train=pd.get_dummies(X_train,columns=['Embarked','Sex','Cabin_Class','Pclass','Title'], drop_first=True)
    X_train.drop(['Cabin','Ticket','Name'], axis=1, inplace=True)

    return X_train
""" X_train['Fam_Count']=X_train['Parch']+X_train['SibSp']
    X_train['Is_alone']=X_train[X_train['Fam_Count']==0].astype(int)"""
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\.'
# <>:8: SyntaxWarning: invalid escape sequence '\.'
# /var/folders/t1/x0nf2pv52cdbz1_9h5q9ctzc0000gn/T/ipykernel_77943/4095590265.py:8: SyntaxWarning: invalid escape sequence '\.'
#   X_train['Title'] = X_train['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
# " X_train['Fam_Count']=X_train['Parch']+X_train['SibSp']\n    X_train['Is_alone']=X_train[X_train['Fam_Count']==0].astype(int)"

# %%
X_train=preprocessing(X_train)

# %%
X_train=X_train.drop('Cabin_Class_T',axis=1)

# %%
Y_train
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
Y_train.nunique()
# Out:
# Survived    2
# dtype: int64

# %% [markdown]
# <h2>Outlier Detection</h2>

# %%
X_train.describe()
# Out:
#               Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000
# mean    29.361582    0.523008    0.381594   32.204208
# std     13.019697    1.102743    0.806057   49.693429
# min      0.420000    0.000000    0.000000    0.000000
# 25%     22.000000    0.000000    0.000000    7.910400
# 50%     28.000000    0.000000    0.000000   14.454200
# 75%     35.000000    1.000000    0.000000   31.000000
# max     80.000000    8.000000    6.000000  512.329200

# %%
data=pd.concat([X_train,Y_train],axis=1)
corr=data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
X_train
# Out:
#       Age  SibSp  Parch     Fare  Has_Cabin  Embarked_Q  Embarked_S  Sex_male  \
# 0    22.0      1      0   7.2500      False       False        True      True
# 1    38.0      1      0  71.2833       True       False       False     False
# 2    26.0      0      0   7.9250      False       False        True     False
# 3    35.0      1      0  53.1000       True       False        True     False
# 4    35.0      0      0   8.0500      False       False        True      True
# ..    ...    ...    ...      ...        ...         ...         ...       ...
# 886  27.0      0      0  13.0000      False       False        True      True
# 887  19.0      0      0  30.0000       True       False        True     False
# 888  28.0      1      2  23.4500      False       False        True     False
# 889  26.0      0      0  30.0000       True       False       False      True
# 890  32.0      0      0   7.7500      False        True       False      True
#
#      Cabin_Class_B  Cabin_Class_C  ...  Cabin_Class_F  Cabin_Class_G  \
# 0            False          False  ...          False          False
# 1            False           True  ...          False          False
# 2            False          False  ...          False          False
# 3            False           True  ...          False          False
# 4            False          False  ...          False          False
# ..             ...            ...  ...            ...            ...
# 886          False          False  ...          False          False
# 887           True          False  ...          False          False
# 888          False          False  ...          False          False
# 889          False           True  ...          False          False
# 890          False          False  ...          False          False
#
#      Cabin_Class_Unknown  Pclass_2  Pclass_3  Title_Miss  Title_Mr  Title_Mrs  \
# 0                   True     False      True       False      True      False
# 1                  False     False     False       False     False       True
# 2                   True     False      True        True     False      False
# 3                  False     False     False       False     False       True
# 4                   True     False      True       False      True      False
# ..                   ...       ...       ...         ...       ...        ...
# 886                 True      True     False       False     False      False
# 887                False     False     False        True     False      False
# 888                 True     False      True        True     False      False
# 889                False     False     False       False      True      False
# 890                 True     False      True       False      True      False
#
#      Title_Officer  Title_Royalty
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
# ..             ...            ...
# 886           True          False
# 887          False          False
# 888          False          False
# 889          False          False
# 890          False          False
#
# [891 rows x 22 columns]

# %%
Xmean=X_train.mean()
Xstd=X_train.std()
def norm(X):
    return ((X-Xmean)/Xstd)

# %%
for i in ['Age','Fare']:
    Xmean=X_train[i].mean()
    Xstd=X_train[i].std()
    X_train[i]=norm(X_train[i])
    X_test[i]=norm(X_test[i])

# %%
X_train
# Out:
#           Age  SibSp  Parch      Fare  Has_Cabin  Embarked_Q  Embarked_S  \
# 0   -0.565419      1      0 -0.502163      False       False        True
# 1    0.663488      1      0  0.786404       True       False       False
# 2   -0.258192      0      0 -0.488580      False       False        True
# 3    0.433068      1      0  0.420494       True       False        True
# 4    0.433068      0      0 -0.486064      False       False        True
# ..        ...    ...    ...       ...        ...         ...         ...
# 886 -0.181385      0      0 -0.386454      False       False        True
# 887 -0.795839      0      0 -0.044356       True       False        True
# 888 -0.104579      1      2 -0.176164      False       False        True
# 889 -0.258192      0      0 -0.044356       True       False       False
# 890  0.202648      0      0 -0.492101      False        True       False
#
#      Sex_male  Cabin_Class_B  Cabin_Class_C  ...  Cabin_Class_F  \
# 0        True          False          False  ...          False
# 1       False          False           True  ...          False
# 2       False          False          False  ...          False
# 3       False          False           True  ...          False
# 4        True          False          False  ...          False
# ..        ...            ...            ...  ...            ...
# 886      True          False          False  ...          False
# 887     False           True          False  ...          False
# 888     False          False          False  ...          False
# 889      True          False           True  ...          False
# 890      True          False          False  ...          False
#
#      Cabin_Class_G  Cabin_Class_Unknown  Pclass_2  Pclass_3  Title_Miss  \
# 0            False                 True     False      True       False
# 1            False                False     False     False       False
# 2            False                 True     False      True        True
# 3            False                False     False     False       False
# 4            False                 True     False      True       False
# ..             ...                  ...       ...       ...         ...
# 886          False                 True      True     False       False
# 887          False                False     False     False        True
# 888          False                 True     False      True        True
# 889          False                False     False     False       False
# 890          False                 True     False      True       False
#
#      Title_Mr  Title_Mrs  Title_Officer  Title_Royalty
# 0        True      False          False          False
# 1       False       True          False          False
# 2       False      False          False          False
# 3       False       True          False          False
# 4        True      False          False          False
# ..        ...        ...            ...            ...
# 886     False      False           True          False
# 887     False      False          False          False
# 888     False      False          False          False
# 889      True      False          False          False
# 890      True      False          False          False
#
# [891 rows x 22 columns]

# %%
X_train.isna().sum()
# Out:
# Age                    0
# SibSp                  0
# Parch                  0
# Fare                   0
# Has_Cabin              0
# Embarked_Q             0
# Embarked_S             0
# Sex_male               0
# Cabin_Class_B          0
# Cabin_Class_C          0
# Cabin_Class_D          0
# Cabin_Class_E          0
# Cabin_Class_F          0
# Cabin_Class_G          0
# Cabin_Class_Unknown    0
# Pclass_2               0
# Pclass_3               0
# Title_Miss             0
# Title_Mr               0
# Title_Mrs              0
# Title_Officer          0
# Title_Royalty          0
# dtype: int64

# %%
X_train = X_train.to_numpy()
Y_train = Y_train.to_numpy()

# %% [markdown]
# <h1>Training</h1>

# %%
def z_calc(X,W,B):
    Z=np.matmul(X,W)+B
    Z = np.clip(Z, -500, 500)
    return Z

def g_calc(Z):
    Z = np.array(Z, dtype=float)
    return 1/(1+np.exp(-Z))

def compute_cost(Y_train,G_train,W_train,lambd=0):
    epsilon=1e-15
    G_train=np.clip(G_train, epsilon, 1 - epsilon)
    cost=-(Y_train*np.log(G_train)+(1-Y_train)*np.log(1-G_train))/G_train.shape[0]
    reg = (lambd / (2 * Y_train.size)) * np.sum(W_train**2)
    return cost.sum()+reg

# %%
W_train = np.ones((X_train.shape[1], 1))
B_train= 0.0

# %%
Z_train=z_calc(X_train,W_train,B_train)
G_train=g_calc(Z_train)
P_train=np.round(G_train)

# %%
print(X_train.shape)
print(Y_train.shape)
print(Z_train.shape)
# Out:
# (891, 22)
# (891, 1)
# (891, 1)

# %%
W_history=[]
B_history=[]
P_history=[]
J_history=[]
W_history.append(W_train)
B_history.append(B_train)
P_history.append(P_train)
J_history.append(compute_cost(Y_train,G_train,W_train))

# %%
def gradescent(epoch, alpha, W_history, J_history, B_history, P_history, X_train, Y_train, lambd=0):
    for i in range(epoch):
        W_current = W_history[-1]
        B_current = B_history[-1]

        Z_train = z_calc(X_train, W_current, B_current)
        G_train = g_calc(Z_train)

        # Gradient updates
        W_new = W_current - alpha* (X_train.T @ (G_train - Y_train) + lambd * W_current) / X_train.shape[0] 
        B_new = B_current - alpha / X_train.shape[0] * np.sum(G_train - Y_train)

        # Append new weights and biases
        W_history.append(W_new.copy())
        B_history.append(B_new)

        # Prediction and cost
        Z_train = z_calc(X_train, W_new, B_new)
        G_train = g_calc(Z_train)
        P_history.append(np.round(G_train))
        J_history.append(compute_cost(Y_train, G_train,W_history[-1]))

        if i % 10 == 0:
            print("Iteration:", i, "Cost:", J_history[-1])

# %%
epoch=3000
alpha=4.5
gradescent(epoch, alpha, W_history, J_history, B_history, P_history, X_train, Y_train)
# Out:
# Iteration: 0 Cost: 1.6353275065154929
# Iteration: 10 Cost: 0.514154415540629
# Iteration: 20 Cost: 0.4710029230453707
# Iteration: 30 Cost: 0.46550653011323373
# Iteration: 40 Cost: 0.4592121005999285
# Iteration: 50 Cost: 0.45547179240121916
# Iteration: 60 Cost: 0.4524956996167062
# Iteration: 70 Cost: 0.4501560986026289
# Iteration: 80 Cost: 0.44821637735951114
# Iteration: 90 Cost: 0.4465691034220062
# Iteration: 100 Cost: 0.44514294143886357
# Iteration: 110 Cost: 0.4438899068341388
# Iteration: 120 Cost: 0.4427767059311368
# Iteration: 130 Cost: 0.4417787743731049
# Iteration: 140 Cost: 0.440877544412739
# Iteration: 150 Cost: 0.44005856189777703
# Iteration: 160 Cost: 0.43931034116934986
# Iteration: 170 Cost: 0.4386235975416737
# Iteration: 180 Cost: 0.43799071662575684
# Iteration: 190 Cost: 0.43740537704062815
# Iteration: 200 Cost: 0.43686227423507273
# Iteration: 210 Cost: 0.43635691428874834
# Iteration: 220 Cost: 0.4358854572269944
# Iteration: 230 Cost: 0.43544459621584997
# Iteration: 240 Cost: 0.4350314632534093
# Iteration: 250 Cost: 0.4346435547287437
# Iteration: 260 Cost: 0.4342786720770494
# Iteration: 270 Cost: 0.43393487403765346
# Iteration: 280 Cost: 0.43361043792157766
# Iteration: 290 Cost: 0.4333038279403769
# Iteration: 300 Cost: 0.4330136691169946
# Iteration: 310 Cost: 0.4327387256446616
# Iteration: 320 Cost: 0.43247788281689237
# Iteration: 330 Cost: 0.4322301318447519
# Iteration: 340 Cost: 0.4319945570240479
# Iteration: 350 Cost: 0.43177032482710004
# Iteration: 360 Cost: 0.43155667458007774
# Iteration: 370 Cost: 0.43135291045396534
# Iteration: 380 Cost: 0.43115839454968813
# Iteration: 390 Cost: 0.43097254089928705
# Iteration: 400 Cost: 0.4307948102378085
# Iteration: 410 Cost: 0.43062470542676334
# Iteration: 420 Cost: 0.430461767430992
# Iteration: 430 Cost: 0.4303055717677329
# Iteration: 440 Cost: 0.4301557253604183
# Iteration: 450 Cost: 0.4300118637409156
# Iteration: 460 Cost: 0.42987364855307175
# Iteration: 470 Cost: 0.4297407653179274
# Iteration: 480 Cost: 0.4296129214271467
# Iteration: 490 Cost: 0.4294898443363069
# Iteration: 500 Cost: 0.42937127993393104
# Iteration: 510 Cost: 0.4292569910656502
# Iteration: 520 Cost: 0.42914675619581777
# Iteration: 530 Cost: 0.42904036819134306
# Iteration: 540 Cost: 0.4289376332145646
# Iteration: 550 Cost: 0.42883836971371336
# Iteration: 560 Cost: 0.4287424075009705
# Iteration: 570 Cost: 0.42864958690936394
# Iteration: 580 Cost: 0.4285597580207937
# Iteration: 590 Cost: 0.4284727799583844
# Iteration: 600 Cost: 0.4283885202371195
# Iteration: 610 Cost: 0.4283068541673899
# Iteration: 620 Cost: 0.42822766430665304
# Iteration: 630 Cost: 0.4281508399549073
# Iteration: 640 Cost: 0.4280762766901166
# Iteration: 650 Cost: 0.4280038759401073
# Iteration: 660 Cost: 0.4279335445877964
# Iteration: 670 Cost: 0.4278651946069074
# Iteration: 680 Cost: 0.4277987427255985
# Iteration: 690 Cost: 0.4277341101156631
# Iteration: 700 Cost: 0.4276712221051741
# Iteration: 710 Cost: 0.4276100079126374
# Iteration: 720 Cost: 0.42755040040088477
# Iteration: 730 Cost: 0.42749233584909907
# Iteration: 740 Cost: 0.42743575374149745
# Iteration: 750 Cost: 0.427380596571329
# Iteration: 760 Cost: 0.4273268096589594
# Iteration: 770 Cost: 0.4272743409829135
# Iteration: 780 Cost: 0.42722314102285075
# Iteration: 790 Cost: 0.42717316261352767
# Iteration: 800 Cost: 0.4271243608088854
# Iteration: 810 Cost: 0.4270766927554696
# Iteration: 820 Cost: 0.4270301175744586
# Iteration: 830 Cost: 0.42698459625163354
# Iteration: 840 Cost: 0.4269400915346813
# Iteration: 850 Cost: 0.42689656783726926
# Iteration: 860 Cost: 0.42685399114938033
# Iteration: 870 Cost: 0.42681232895343485
# Iteration: 880 Cost: 0.4267715501457671
# Iteration: 890 Cost: 0.42673162496305994
# Iteration: 900 Cost: 0.4266925249133713
# Iteration: 910 Cost: 0.42665422271141606
# Iteration: 920 Cost: 0.4266166922177974
# Iteration: 930 Cost: 0.42657990838190224
# Iteration: 940 Cost: 0.42654384718819843
# Iteration: 950 Cost: 0.4265084856056969
# Iteration: 960 Cost: 0.42647380154035486
# Iteration: 970 Cost: 0.4264397737902173
# Iteration: 980 Cost: 0.42640638200310943
# Iteration: 990 Cost: 0.42637360663670637
# Iteration: 1000 Cost: 0.42634142892082083
# Iteration: 1010 Cost: 0.426309830821762
# Iteration: 1020 Cost: 0.42627879500862875
# Iteration: 1030 Cost: 0.4262483048214121
# Iteration: 1040 Cost: 0.4262183442407898
# Iteration: 1050 Cost: 0.42618889785950786
# Iteration: 1060 Cost: 0.42615995085524644
# Iteration: 1070 Cost: 0.42613148896488073
# Iteration: 1080 Cost: 0.42610349846005025
# Iteration: 1090 Cost: 0.4260759661239556
# Iteration: 1100 Cost: 0.42604887922931356
# Iteration: 1110 Cost: 0.4260222255173984
# Iteration: 1120 Cost: 0.4259959931781059
# Iteration: 1130 Cost: 0.4259701708309839
# Iteration: 1140 Cost: 0.4259447475071726
# Iteration: 1150 Cost: 0.425919712632202
# Iteration: 1160 Cost: 0.425895056009602
# Iteration: 1170 Cost: 0.42587076780527655
# Iteration: 1180 Cost: 0.42584683853260547
# Iteration: 1190 Cost: 0.4258232590382274
# Iteration: 1200 Cost: 0.4258000204884759
# Iteration: 1210 Cost: 0.42577711435642945
# Iteration: 1220 Cost: 0.4257545324095432
# Iteration: 1230 Cost: 0.42573226669783404
# Iteration: 1240 Cost: 0.4257103095425925
# Iteration: 1250 Cost: 0.4256886535255908
# Iteration: 1260 Cost: 0.42566729147876536
# Iteration: 1270 Cost: 0.4256462164743494
# Iteration: 1280 Cost: 0.4256254218154344
# Iteration: 1290 Cost: 0.425604901026937
# Iteration: 1300 Cost: 0.42558464784695565
# Iteration: 1310 Cost: 0.4255646562184957
# Iteration: 1320 Cost: 0.4255449202815452
# Iteration: 1330 Cost: 0.42552543436548945
# Iteration: 1340 Cost: 0.4255061929818411
# Iteration: 1350 Cost: 0.4254871908172774
# Iteration: 1360 Cost: 0.42546842272696916
# Iteration: 1370 Cost: 0.4254498837281853
# Iteration: 1380 Cost: 0.4254315689941642
# Iteration: 1390 Cost: 0.42541347384823797
# Iteration: 1400 Cost: 0.4253955937581979
# Iteration: 1410 Cost: 0.42537792433089217
# Iteration: 1420 Cost: 0.4253604613070438
# Iteration: 1430 Cost: 0.4253432005562799
# Iteration: 1440 Cost: 0.4253261380723635
# Iteration: 1450 Cost: 0.42530926996861773
# Iteration: 1460 Cost: 0.4252925924735361
# Iteration: 1470 Cost: 0.4252761019265681
# Iteration: 1480 Cost: 0.42525979477407555
# Iteration: 1490 Cost: 0.42524366756545
# Iteration: 1500 Cost: 0.4252277169493863
# Iteration: 1510 Cost: 0.4252119396703032
# Iteration: 1520 Cost: 0.4251963325649083
# Iteration: 1530 Cost: 0.42518089255889757
# Iteration: 1540 Cost: 0.42516561666378605
# Iteration: 1550 Cost: 0.42515050197386367
# Iteration: 1560 Cost: 0.42513554566327166
# Iteration: 1570 Cost: 0.4251207449831924
# Iteration: 1580 Cost: 0.42510609725915005
# Iteration: 1590 Cost: 0.4250915998884175
# Iteration: 1600 Cost: 0.42507725033752297
# Iteration: 1610 Cost: 0.42506304613985557
# Iteration: 1620 Cost: 0.42504898489336207
# Iteration: 1630 Cost: 0.4250350642583337
# Iteration: 1640 Cost: 0.42502128195527855
# Iteration: 1650 Cost: 0.4250076357628757
# Iteration: 1660 Cost: 0.4249941235160092
# Iteration: 1670 Cost: 0.4249807431038748
# Iteration: 1680 Cost: 0.4249674924681629
# Iteration: 1690 Cost: 0.42495436960130806
# Iteration: 1700 Cost: 0.424941372544806
# Iteration: 1710 Cost: 0.4249284993875953
# Iteration: 1720 Cost: 0.42491574826449985
# Iteration: 1730 Cost: 0.4249031173547297
# Iteration: 1740 Cost: 0.4248906048804406
# Iteration: 1750 Cost: 0.42487820910534435
# Iteration: 1760 Cost: 0.42486592833337505
# Iteration: 1770 Cost: 0.42485376090740246
# Iteration: 1780 Cost: 0.4248417052079947
# Iteration: 1790 Cost: 0.42482975965222747
# Iteration: 1800 Cost: 0.42481792269253527
# Iteration: 1810 Cost: 0.42480619281560916
# Iteration: 1820 Cost: 0.4247945685413308
# Iteration: 1830 Cost: 0.4247830484217488
# Iteration: 1840 Cost: 0.4247716310400915
# Iteration: 1850 Cost: 0.42476031500981626
# Iteration: 1860 Cost: 0.42474909897369284
# Iteration: 1870 Cost: 0.424737981602921
# Iteration: 1880 Cost: 0.42472696159627976
# Iteration: 1890 Cost: 0.42471603767930777
# Iteration: 1900 Cost: 0.4247052086035117
# Iteration: 1910 Cost: 0.4246944731456049
# Iteration: 1920 Cost: 0.42468383010677346
# Iteration: 1930 Cost: 0.42467327831196644
# Iteration: 1940 Cost: 0.42466281660921334
# Iteration: 1950 Cost: 0.42465244386896484
# Iteration: 1960 Cost: 0.42464215898345686
# Iteration: 1970 Cost: 0.4246319608660972
# Iteration: 1980 Cost: 0.42462184845087425
# Iteration: 1990 Cost: 0.42461182069178455
# Iteration: 2000 Cost: 0.4246018765622827
# Iteration: 2010 Cost: 0.424592015054748
# Iteration: 2020 Cost: 0.4245822351799714
# Iteration: 2030 Cost: 0.42457253596665934
# Iteration: 2040 Cost: 0.42456291646095357
# Iteration: 2050 Cost: 0.4245533757259692
# Iteration: 2060 Cost: 0.42454391284134785
# Iteration: 2070 Cost: 0.42453452690282434
# Iteration: 2080 Cost: 0.4245252170218101
# Iteration: 2090 Cost: 0.42451598232498944
# Iteration: 2100 Cost: 0.4245068219539299
# Iteration: 2110 Cost: 0.4244977350647049
# Iteration: 2120 Cost: 0.4244887208275284
# Iteration: 2130 Cost: 0.4244797784264039
# Iteration: 2140 Cost: 0.4244709070587812
# Iteration: 2150 Cost: 0.4244621059352293
# Iteration: 2160 Cost: 0.42445337427911406
# Iteration: 2170 Cost: 0.42444471132629114
# Iteration: 2180 Cost: 0.4244361163248066
# Iteration: 2190 Cost: 0.42442758853460694
# Iteration: 2200 Cost: 0.4244191272272597
# Iteration: 2210 Cost: 0.424410731685681
# Iteration: 2220 Cost: 0.424402401203873
# Iteration: 2230 Cost: 0.42439413508666923
# Iteration: 2240 Cost: 0.42438593264948815
# Iteration: 2250 Cost: 0.42437779321809316
# Iteration: 2260 Cost: 0.42436971612836183
# Iteration: 2270 Cost: 0.42436170072606016
# Iteration: 2280 Cost: 0.4243537463666254
# Iteration: 2290 Cost: 0.42434585241495426
# Iteration: 2300 Cost: 0.42433801824519857
# Iteration: 2310 Cost: 0.4243302432405651
# Iteration: 2320 Cost: 0.4243225267931249
# Iteration: 2330 Cost: 0.4243148683036231
# Iteration: 2340 Cost: 0.42430726718129974
# Iteration: 2350 Cost: 0.42429972284371165
# Iteration: 2360 Cost: 0.4242922347165622
# Iteration: 2370 Cost: 0.42428480223353326
# Iteration: 2380 Cost: 0.4242774248361253
# Iteration: 2390 Cost: 0.42427010197349935
# Iteration: 2400 Cost: 0.42426283310232427
# Iteration: 2410 Cost: 0.42425561768662834
# Iteration: 2420 Cost: 0.42424845519765564
# Iteration: 2430 Cost: 0.4242413451137246
# Iteration: 2440 Cost: 0.42423428692009274
# Iteration: 2450 Cost: 0.42422728010882294
# Iteration: 2460 Cost: 0.4242203241786553
# Iteration: 2470 Cost: 0.4242134186348804
# Iteration: 2480 Cost: 0.4242065629892177
# Iteration: 2490 Cost: 0.42419975675969657
# Iteration: 2500 Cost: 0.4241929994705398
# Iteration: 2510 Cost: 0.4241862906520508
# Iteration: 2520 Cost: 0.4241796298405043
# Iteration: 2530 Cost: 0.4241730165780383
# Iteration: 2540 Cost: 0.42416645041254997
# Iteration: 2550 Cost: 0.4241599308975941
# Iteration: 2560 Cost: 0.42415345759228384
# Iteration: 2570 Cost: 0.42414703006119403
# Iteration: 2580 Cost: 0.4241406478742664
# Iteration: 2590 Cost: 0.42413431060671813
# Iteration: 2600 Cost: 0.4241280178389517
# Iteration: 2610 Cost: 0.42412176915646815
# Iteration: 2620 Cost: 0.42411556414978024
# Iteration: 2630 Cost: 0.4241094024143303
# Iteration: 2640 Cost: 0.4241032835504079
# Iteration: 2650 Cost: 0.4240972071630709
# Iteration: 2660 Cost: 0.424091172862068
# Iteration: 2670 Cost: 0.42408518026176173
# Iteration: 2680 Cost: 0.42407922898105554
# Iteration: 2690 Cost: 0.424073318643321
# Iteration: 2700 Cost: 0.4240674488763265
# Iteration: 2710 Cost: 0.4240616193121688
# Iteration: 2720 Cost: 0.4240558295872051
# Iteration: 2730 Cost: 0.42405007934198663
# Iteration: 2740 Cost: 0.4240443682211942
# Iteration: 2750 Cost: 0.4240386958735751
# Iteration: 2760 Cost: 0.424033061951881
# Iteration: 2770 Cost: 0.42402746611280695
# Iteration: 2780 Cost: 0.42402190801693235
# Iteration: 2790 Cost: 0.42401638732866365
# Iteration: 2800 Cost: 0.4240109037161764
# Iteration: 2810 Cost: 0.42400545685136004
# Iteration: 2820 Cost: 0.4240000464097635
# Iteration: 2830 Cost: 0.42399467207054203
# Iteration: 2840 Cost: 0.4239893335164042
# Iteration: 2850 Cost: 0.42398403043356125
# Iteration: 2860 Cost: 0.4239787625116769
# Iteration: 2870 Cost: 0.42397352944381717
# Iteration: 2880 Cost: 0.4239683309264043
# Iteration: 2890 Cost: 0.423963166659167
# Iteration: 2900 Cost: 0.4239580363450951
# Iteration: 2910 Cost: 0.42395293969039477
# Iteration: 2920 Cost: 0.42394787640444254
# Iteration: 2930 Cost: 0.423942846199743
# Iteration: 2940 Cost: 0.4239378487918842
# Iteration: 2950 Cost: 0.42393288389949724
# Iteration: 2960 Cost: 0.42392795124421384
# Iteration: 2970 Cost: 0.42392305055062524
# Iteration: 2980 Cost: 0.4239181815462447
# Iteration: 2990 Cost: 0.4239133439614656

# %%
"""
1- Initial Cost: 0.5385007707265328
2- Cost after not normalising categorical variables: 0.4478993080479844
3- Best: 0.42355900984175"""
# Out:
# '\n1- Initial Cost: 0.5385007707265328\n2- Cost after not normalising categorical variables: 0.4478993080479844\n3- Best: 0.42355900984175'

# %%
plt.plot(J_history)

# %%
W_train=W_history[-1]
B_train=B_history[-1]
Z_train=z_calc(X_train,W_train,B_train)
G_train=g_calc(Z_train)
P_train=np.round(G_train)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_train, P_train)  
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_train, P_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.87       549
#            1       0.87      0.66      0.75       342
#
#     accuracy                           0.83       891
#    macro avg       0.84      0.80      0.81       891
# weighted avg       0.84      0.83      0.83       891

# %%
count=0
for i in range(len(P_train)):
    if (P_train[i]==Y_train[i]):
        count+=1
print("Accuracy: ",count*100/len(P_train))
# Out:
# Accuracy:  83.27721661054994

# %%
"""
Accuracy 1 (Initial): 76.767676
Accuracy 2 (Fixing normalisation problem): 79.2368125701459
Accuracy 3 (got dummies for Pclass too and drop_first=True): 82.04264870931537 
Accuracy 4 (using titles from names) 83.27721661054994

"""
# Out:
# '\nAccuracy 1 (Initial): 76.767676\nAccuracy 2 (Fixing normalisation problem): 79.2368125701459\nAccuracy 3 (got dummies for Pclass too and drop_first=True): 82.04264870931537 \nAccuracy 4 (using titles from names) 83.27721661054994\n\n'

# %%
"""
What to do:
    1-learn what improves accuracy and what improves recall and how to influence them
    




"""
# Out:
# '\nWhat to do:\n    1-learn what improves accuracy and what improves recall and how to influence them\n    \n\n\n\n\n'

# %% [markdown]
# <h1>Testing</h1>

# %%
X_test
# Out:
#      Pclass                                          Name     Sex       Age  \
# 0         3                              Kelly, Mr. James    male  0.394665
# 1         3              Wilkes, Mrs. James (Ellen Needs)  female  1.354749
# 2         2                     Myles, Mr. Thomas Francis    male  2.506849
# 3         3                              Wirz, Mr. Albert    male -0.181385
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female -0.565419
# ..      ...                                           ...     ...       ...
# 413       3                            Spector, Mr. Woolf    male       NaN
# 414       1                  Oliva y Ocana, Dona. Fermina  female  0.740295
# 415       3                  Saether, Mr. Simon Sivertsen    male  0.701892
# 416       3                           Ware, Mr. Frederick    male       NaN
# 417       3                      Peter, Master. Michael J    male       NaN
#
#      SibSp  Parch              Ticket      Fare Cabin Embarked
# 0        0      0              330911 -0.490508   NaN        Q
# 1        1      0              363272 -0.507194   NaN        S
# 2        0      0              240276 -0.453112   NaN        Q
# 3        0      0              315154 -0.473739   NaN        S
# 4        1      1             3101298 -0.400792   NaN        S
# ..     ...    ...                 ...       ...   ...      ...
# 413      0      0           A.5. 3236 -0.486064   NaN        S
# 414      0      0            PC 17758  1.543379  C105        C
# 415      0      0  SOTON/O.Q. 3101262 -0.502163   NaN        S
# 416      0      0              359309 -0.486064   NaN        S
# 417      1      1                2668 -0.198133   NaN        C
#
# [418 rows x 10 columns]

# %%
X_test=preprocessing(X_test)
X_test=X_test.to_numpy()

# %%
y_pred=z_calc(X_test,W_train,B_train)
g_pred=g_calc(y_pred)
p_pred=np.round(g_pred)

# %%
Y_test=Y_test.drop('PassengerId',axis=1)

# %%
Y_test=Y_test.to_numpy()

# %%
cm = confusion_matrix(Y_test, p_pred)  
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(Y_test, p_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92       266
#            1       0.89      0.80      0.84       152
#
#     accuracy                           0.89       418
#    macro avg       0.89      0.87      0.88       418
# weighted avg       0.89      0.89      0.89       418

# %%
count=0
for i in range(len(p_pred)):
    if (p_pred[i]==Y_test[i]):
        count+=1
print("Accuracy: ",count*100/len(p_pred))
# Out:
# Accuracy:  88.99521531100478
