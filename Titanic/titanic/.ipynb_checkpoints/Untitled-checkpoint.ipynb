# %%
import numpy as np

# %%
calla=[136,145,139,132,141,143,139,139]
callb = [124,131,128,130,129,135,132]
callc=[142,145,139,145,143,141,138,146]
calld=[149,157,154,155,151,156]

# %%
sp = ((n1-1)*s1**2+(n2-1)*s2**2)**.5/(n1+n2-1)
T = (x1.mean - x2.mean)/(sp*(1/n1+1/n2)**.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 T = (x1.mean - x2.mean)/(sp*root(1/n1+1/n2))
#
# NameError: name 'x1' is not defined
